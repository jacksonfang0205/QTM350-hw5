# %% [markdown]
# ---
# title: QTM350-hw5
# author: Jackson Fang
# date: 02/21/2025
# format:
#     html:
#         code-fold: true
# keep-ipynb: true
# ---

# %% [markdown]
# # HW5

# %% [markdown]
# ## Q1 Load Data

# %%
cd /Users/jackson/Documents/emory/emory2025Spring/QTM350/QTM350-hw5
# Out:
# /Users/jackson/Documents/emory/emory2025Spring/QTM350/QTM350-hw5

# %%
import pandas as pd
import numpy as np
# Out:
# /Users/jackson/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data = pd.read_csv('wdi.csv')

# %%
data[data['country'] =='Lebanon']
# Out:
#      country  inflation_rate  exports_gdp_share  gdp_growth_rate  \
# 110  Lebanon      171.205491          34.828779        -0.621679
#
#      gdp_per_capita  adult_literacy_rate  primary_school_enrolment_rate  \
# 110     3823.938069                  NaN                            NaN
#
#      education_expenditure_gdp_share  measles_immunisation_rate  \
# 110                              NaN                       67.0
#
#      health_expenditure_gdp_share  income_inequality  unemployment_rate  \
# 110                           NaN                NaN             11.599
#
#      life_expectancy  total_population
# 110           74.416         5489739.0

# %% [markdown]
# ## Q2 Exploratory Data Analysis

# %% [markdown]
# ### Which country has the highest GDP per capita
# ### Which country has the highest GDP growth rate
# ### What is the average inflation rate

# %%
# Find which country has the highest GDP per capita
country_with_highest_gdp = data.loc[data['gdp_per_capita'].idxmax()]['country']
print(f"The country with the highest GDP per capita is {country_with_highest_gdp}. Its gdp is {data['gdp_per_capita'].max()}.")

# Find which country has the highest GDP growth rate
country_with_highest_gdp_growth = data.loc[data['gdp_growth_rate'].idxmax()]['country']
print(f"The country with the highest GDP growth rate is {country_with_highest_gdp_growth}. Its gdp growth rate is {data['gdp_growth_rate'].max()}%.")

# Calculate the average inflation rate
average_inflation_rate = data['inflation_rate'].mean()
print(f"The average inflation rate across all countries is {average_inflation_rate:.2f}%.")
# Out:
# The country with the highest GDP per capita is Monaco. Its gdp is 240862.18244774.
# The country with the highest GDP growth rate is Guyana. Its gdp growth rate is 63.4398643665041%.
# The average inflation rate across all countries is 12.49%.
# Lebanon

# %% [markdown]
# ## Q3 Two Plots Showing My Data Analysis

# %%
import matplotlib.pyplot as plt

top_countries = data.nlargest(10, 'gdp_per_capita')

plt.figure(figsize=(10, 6))
plt.bar(top_countries['country'], top_countries['gdp_per_capita'], color='skyblue')
plt.title('Top 10 Countries by GDP Per Capita')
plt.xlabel('Country')
plt.ylabel('GDP Per Capita')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Assuming 'data' also includes 'gdp_growth_rate'
top_countries = data.nlargest(10, 'gdp_growth_rate')
plt.figure(figsize=(10, 6))
plt.scatter(top_countries['country'], top_countries['gdp_growth_rate'], color='green')
plt.title('GDP Growth Rate by Country')
plt.xlabel('Country')
plt.ylabel('GDP Growth Rate (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
